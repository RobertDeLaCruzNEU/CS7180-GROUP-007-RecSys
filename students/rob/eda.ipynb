# %% [markdown]
# # Exploratory Data Analysis of KuaiRand 1k dataset
#
# **Prepare**
# - Import data
# - Clean data
# - Relabel

# %%
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
import torch
